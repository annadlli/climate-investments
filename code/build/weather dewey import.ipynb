# %%
#setup
import numpy as np
import pandas as pd
import scipy as scipy
import matplotlib.pyplot as plt
import deweydatapy as ddp
import os
import re

new_dir = "/Users/anna/Desktop/climate-investments"
os.chdir(new_dir)
# API Key
apikey = "akv1_rmWv0DXQ-2jsoB2tLp9csaYBx7X_xIWBYg6"#property
# Product path
pp3 = "https://api.deweydata.io/api/v1/external/data/cdst_mvcmq6bddeh3od8n" #building permits Builty South Florida
pp4= "https://api.deweydata.io/api/v1/external/data/cdst_ygtmdjcysbfxr7di" #building permits Builty California

# %%
files_df = ddp.get_file_list(apikey, pp3, 
                             print_info = True)
output_dir = os.path.join(new_dir, "/data/raw")
ddp.download_files(files_df, output_dir,skip_exists=True)
# Out:
# Collecting files information for page 1/2...
# Collecting files information for page 2/2...
# Files information collection completed.
#
# Files information summary ---------------------------------------
# Total number of pages: 2
# Total number of files: 64
# Total files size (MB): 5,253.1
# Average single file size (MB): 82.92
# Date partition column: None
# Expires at: 2025-11-15T20:19:19.083952+00:00
# -----------------------------------------------------------------
# Downloading 1/64 (file index = 0)
# Writing /Users/anna/Desktop/research/buildingpermits/building-permits-united-states_0_0_0.csv.gz
# Please be patient. It may take a while...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 4
#       1 files_df = ddp.get_file_list(apikey, pp3,
#       2                              print_info = True)
#       3 output_dir = os.path.join(new_dir, "buildingpermits")
# ----> 4 ddp.download_files(files_df, output_dir, skip_exists=True)
#
# File /opt/anaconda3/lib/python3.12/site-packages/deweydatapy/download.py:335, in download_files(files_df, dest_folder, filename_prefix, skip_exists)
#     332 print("Please be patient. It may take a while...")
#     333 sys.stdout.flush()
# --> 335 response = requests.get(files_df['link'][i])
#     336 open(dest_path, 'wb').write(response.content)
#     337 print(f"   ")
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:724, in Session.send(self, request, **kwargs)
#     721 if allow_redirects:
#     722     # Redirect resolving generator.
#     723     gen = self.resolve_redirects(r, request, **kwargs)
# --> 724     history = [resp for resp in gen]
#     725 else:
#     726     history = []
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:265, in SessionRedirectMixin.resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     263     yield req
#     264 else:
# --> 265     resp = self.send(
#     266         req,
#     267         stream=stream,
#     268         timeout=timeout,
#     269         verify=verify,
#     270         cert=cert,
#     271         proxies=proxies,
#     272         allow_redirects=False,
#     273         **adapter_kwargs,
#     274     )
#     276     extract_cookies_to_jar(self.cookies, prepared_request, resp.raw)
#     278     # extract redirect url, if any, for the next loop
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/response.py:1060, in HTTPResponse.stream(self, amt, decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# -> 1060         data = self.read(amt=amt, decode_content=decode_content)
#    1062         if data:
#    1063             yield data
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/response.py:949, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     946     if len(self._decoded_buffer) >= amt:
#     947         return self._decoded_buffer.get(amt)
# --> 949 data = self._raw_read(amt)
#     951 flush_decoder = amt is None or (amt != 0 and not data)
#     953 if not data and len(self._decoded_buffer) == 0:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/response.py:873, in HTTPResponse._raw_read(self, amt, read1)
#     870 fp_closed = getattr(self._fp, "closed", False)
#     872 with self._error_catcher():
# --> 873     data = self._fp_read(amt, read1=read1) if not fp_closed else b""
#     874     if amt is not None and amt != 0 and not data:
#     875         # Platform-specific: Buggy versions of Python.
#     876         # Close the connection when no data is returned
#    (...)
#     881         # not properly close the connection in all cases. There is
#     882         # no harm in redundantly calling close.
#     883         self._fp.close()
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/response.py:856, in HTTPResponse._fp_read(self, amt, read1)
#     853     return self._fp.read1(amt) if amt is not None else self._fp.read1()
#     854 else:
#     855     # StringIO doesn't like amt=None
# --> 856     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File /opt/anaconda3/lib/python3.12/http/client.py:479, in HTTPResponse.read(self, amt)
#     476 if self.length is not None and amt > self.length:
#     477     # clip the read to the "end of response"
#     478     amt = self.length
# --> 479 s = self.fp.read(amt)
#     480 if not s and amt:
#     481     # Ideally, we would raise IncompleteRead if the content-length
#     482     # wasn't satisfied, but it might break compatibility.
#     483     self._close_conn()
#
# File /opt/anaconda3/lib/python3.12/socket.py:708, in SocketIO.readinto(self, b)
#     706 while True:
#     707     try:
# --> 708         return self._sock.recv_into(b)
#     709     except timeout:
#     710         self._timeout_occurred = True
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
#fire
files_df = ddp.get_file_list(apikey, pp4,
                             print_info = True)
output_dir_fire = os.path.join(new_dir, "data/fire/raw")

ddp.download_files(files_df, output_dir_fire,skip_exists=True)
# Out:
# Collecting files information for page 1/2...
# Collecting files information for page 2/2...
# Files information collection completed.
#
# Files information summary ---------------------------------------
# Total number of pages: 2
# Total number of files: 66
# Total files size (MB): 15,706.82
# Average single file size (MB): 235.54
# Date partition column: None
# Expires at: 2025-11-15T20:57:33.218718+00:00
# -----------------------------------------------------------------
# Downloading 1/66 (file index = 0)
# Writing /Users/anna/Desktop/climate-investments/data/fire/raw/building-permits-united-states_0_0_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 2/66 (file index = 1)
# Writing /Users/anna/Desktop/climate-investments/data/fire/raw/building-permits-united-states_0_1_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 3/66 (file index = 2)
# Writing /Users/anna/Desktop/climate-investments/data/fire/raw/building-permits-united-states_0_2_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 4/66 (file index = 3)
# Writing /Users/anna/Desktop/climate-investments/data/fire/raw/building-permits-united-states_0_3_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 5/66 (file index = 4)
# Writing /Users/anna/Desktop/climate-investments/data/fire/raw/building-permits-united-states_0_4_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 6/66 (file index = 5)
# Writing /Users/anna/Desktop/climate-investments/data/fire/raw/building-permits-united-states_0_5_0.csv.gz
# Please be patient. It may take a while...
#
# Downloading 7/66 (file index = 6)
# Writing /Users/anna/Desktop/climate-investments/data/fire/raw/building-permits-united-states